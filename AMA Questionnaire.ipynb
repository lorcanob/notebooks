# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pathlib import Path
from openvino.runtime import Core

# %%
csv_path = '/Users/lorcan/Documents/AMA/CSVs/Survey.csv'

# %%
df = pd.read_csv(csv_path)

# %%
df.Timestamp = pd.to_datetime(df.Timestamp)

# %%
i = 4

print(f'Column {i}:\n{df.columns[i]}\n')
print(f'No. of unique values:\n{df.iloc[:,i].nunique()}\n')
print(f'Unique values:\n{df.iloc[:,i].unique()}\n')
# Out:
# Column 4:
# What is your occupation?
#
# No. of unique values:
# 9
#
# Unique values:
# ['Full time' 'Freelance' 'Student' 'Part time' 'Other' 'Unemployed'
#  'Company Executive' 'Retired' 'Disabled or not able to work']

# %%
df
# Out:
#               Timestamp                             ID What is your gender?  \
# 0   2022-05-21 11:34:55  lorcanodufuwabolger@gmail.com                 Male
# 1   2022-05-23 17:02:15         williamjunec@gmail.com                 Male
# 2   2022-05-23 17:30:18          carson.k.li@gmail.com                 Male
# 3   2022-05-23 18:31:09            kimtw3035@gmail.com                 Male
# 4   2022-05-23 19:29:02              rahdekh@gmail.com                 Male
# ..                  ...                            ...                  ...
# 188 2022-06-02 17:53:46                        1162507               Female
# 189 2022-06-02 17:56:30                         770021               Female
# 190 2022-06-02 18:03:12                        1489683                 Male
# 191 2022-06-02 18:17:32   mayumayu54@kpa.biglobe.ne.jp               Female
# 192 2022-06-02 18:21:27                         862084               Female
#
#      What is your age? What is your occupation?  \
# 0    20 ~ 29 years old                Full time
# 1    20 ~ 29 years old                Freelance
# 2    30 ~ 39 years old                Full time
# 3    20 ~ 29 years old                Full time
# 4    20 ~ 29 years old                  Student
# ..                 ...                      ...
# 188  50 ~ 59 years old                    Other
# 189  60 ~ 69 years old               Unemployed
# 190  40 ~ 49 years old                Freelance
# 191  60 ~ 69 years old               Unemployed
# 192  50 ~ 59 years old               Unemployed
#
#     How much do you spend on in-app purchases per month?  \
# 0                                                0 yen
# 1                                          1~1,000 yen
# 2                                          1~1,000 yen
# 3                                          1~1,000 yen
# 4                                                0 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                                   5,000~10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     How much do you spend on your hobbies per month?  \
# 0                                   5,000~10,000 yen
# 1                                    1,000~5,000 yen
# 2                                    1,000~5,000 yen
# 3                                    1,000~5,000 yen
# 4                                   5,000~10,000 yen
# ..                                               ...
# 188                                            0 yen
# 189                                10,000~50,000 yen
# 190                             More than 50,000 yen
# 191                                  1,000~5,000 yen
# 192                                            0 yen
#
#     How much do you spend on subscription services per month?  \
# 0                                      1,000~5,000 yen
# 1                                      1,000~5,000 yen
# 2                                          1~1,000 yen
# 3                                      1,000~5,000 yen
# 4                                      1,000~5,000 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                                   5,000~10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     Have you ever spent money on online courses?  \
# 0                                             No
# 1                                            Yes
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 188                                           No
# 189                                           No
# 190                                          Yes
# 191                                           No
# 192                                           No
#
#     This question is only for those who selected "Yes" above. If you have spent money on online courses, how much did you pay?  \
# 0                                                0 yen
# 1                                     5,000~10,000 yen
# 2                                                0 yen
# 3                                                0 yen
# 4                                                0 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 188  ...
# 189  ...
# 190  ...
# 191  ...
# 192  ...
#
#     Would you rather search a complicated question regarding a topic you’re interested in, or pay money and ask a well-known and relevant specialist?  \
# 0                                           Specialist
# 1                                     Search on my own
# 2                                     Search on my own
# 3                                           Specialist
# 4                                     Search on my own
# ..                                                 ...
# 188                                   Search on my own
# 189                                   Search on my own
# 190                                         Specialist
# 191                                   Search on my own
# 192                                   Search on my own
#
#     If you were to ask a specialist a complicated question regarding a topic you’re interested in, how much would you pay?  \
# 0                                          1~1,000 yen
# 1                                     5,000~10,000 yen
# 2                                      1,000~5,000 yen
# 3                                      1,000~5,000 yen
# 4                                                0 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     If you're facing a major career decision/life choice, would you Google, ask a friend, or ask a specialist?  \
# 0              All (Search Engine, Friend, Specialist)
# 1                             Search Engine and Friend
# 2                                        Search Engine
# 3                                Friend and Specialist
# 4                                               Friend
# ..                                                 ...
# 188                                             Friend
# 189                                      Search Engine
# 190                       Search Engine and Specialist
# 191                                             No one
# 192                                         Specialist
#
#     If you had to ask a specialist, would you prefer a response via video or text?  \
# 0                                     A video response
# 1                                     A video response
# 2                                     A video response
# 3                                     A video response
# 4                                     A video response
# ..                                                 ...
# 188                                    A text response
# 189                                    A text response
# 190                                    A text response
# 191                                    A text response
# 192                                   A video response
#
#     If you were to receive a video response, how much would you be willing to pay?  \
# 0                                      1,000~5,000 yen
# 1                                     5,000~10,000 yen
# 2                                      1,000~5,000 yen
# 3                                      1,000~5,000 yen
# 4                                          1~1,000 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     If you were to receive a text response, how much would you be willing to pay?  \
# 0                                          1~1,000 yen
# 1                                          1~1,000 yen
# 2                                          1~1,000 yen
# 3                                          1~1,000 yen
# 4                                          1~1,000 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     If you had a complicated question about your hobby/interest, would you Google it or pay money to ask a well known and relevant specialist?  \
# 0                  Both (Search Engine and Specialist)
# 1                                        Search Engine
# 2                                           Specialist
# 3                                           Specialist
# 4                                        Search Engine
# ..                                                 ...
# 188                                      Search Engine
# 189                                      Search Engine
# 190                Both (Search Engine and Specialist)
# 191                                      Search Engine
# 192                                         Specialist
#
#     With your own hobby/interest in mind - If you had to ask a specialist, how much would you pay?  \
# 0                                          1~1,000 yen
# 1                                      1,000~5,000 yen
# 2                                      1,000~5,000 yen
# 3                                          1~1,000 yen
# 4                                                0 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     If you had the chance to receive a guaranteed personalized video (for an answer to a question or for advice) from an influential figure you admire, how much would you spend?  \
# 0                                      1,000~5,000 yen
# 1                                     5,000~10,000 yen
# 2                                          1~1,000 yen
# 3                                      1,000~5,000 yen
# 4                                          1~1,000 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
#     If you had the chance to receive a guaranteed personalized text (for an answer to a question or for advice) from an influential figure you admire, how much would you spend?
# 0                                          1~1,000 yen
# 1                                      1,000~5,000 yen
# 2                                      1,000~5,000 yen
# 3                                          1~1,000 yen
# 4                                          1~1,000 yen
# ..                                                 ...
# 188                                              0 yen
# 189                                              0 yen
# 190                               More than 10,000 yen
# 191                                              0 yen
# 192                                              0 yen
#
# [193 rows x 26 columns]
